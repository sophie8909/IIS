# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /Users/chenchenghan/Library/Python/3.11/lib/python/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (5.29.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/chenchenghan/Library/Python/3.11/lib/python/site-packages (from tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (1.68.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (3.7.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from keras>=3.5.0->tensorflow) (0.13.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from requests<3,>=2.21.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/chenchenghan/Library/Python/3.11/lib/python/site-packages (from rich->keras>=3.5.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# 定義圖片大小和批量大小
img_size = 48
batch_size = 32

# 使用 ImageDataGenerator 並設置 validation_split
data_generator = ImageDataGenerator(rescale=1./255, validation_split=0.2)

# 訓練集（80%）
train_generator = data_generator.flow_from_directory(
    '/Users/chenchenghan/Downloads/archive/train',  # 替換為你的實際訓練集路徑
    target_size=(img_size, img_size),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical',
    subset='training'  # 訓練子集
)

# 驗證集（20%）
val_generator = data_generator.flow_from_directory(
    '/Users/chenchenghan/Downloads/archive/train',  # 同樣使用訓練集路徑
    target_size=(img_size, img_size),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical',
    subset='validation'  # 驗證子集
)

# 測試集
test_generator = data_generator.flow_from_directory(
    '/Users/chenchenghan/Downloads/archive/test',  # 替換為測試集路徑
    target_size=(img_size, img_size),
    batch_size=batch_size,
    color_mode='grayscale',
    class_mode='categorical'
)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %%
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_size, img_size, 1)),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

# 編譯模型
model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# 訓練模型
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=epochs,
    steps_per_epoch=train_generator.samples // batch_size,
    validation_steps=val_generator.samples // batch_size
)

# 儲存模型
model.save('emotion_detection_fer2013.h5')

# 評估模型
test_loss, test_acc = model.evaluate(test_generator)
print(f"Test Accuracy: {test_acc * 100:.2f}%")
# Out:
# Epoch 1/50
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 16s 21ms/step - accuracy: 0.2363 - loss: 1.8325 - val_accuracy: 0.2977 - val_loss: 1.7031
# Epoch 2/50
#   1/717 ━━━━━━━━━━━━━━━━━━━━ 13s 19ms/step - accuracy: 0.1250 - loss: 1.7937
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/keras/src/trainers/epoch_iterator.py:107: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.1250 - loss: 1.7937 - val_accuracy: 0.2989 - val_loss: 1.7030
# Epoch 3/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 16s 22ms/step - accuracy: 0.3294 - loss: 1.6793 - val_accuracy: 0.4190 - val_loss: 1.4979
# Epoch 4/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3750 - loss: 1.5398 - val_accuracy: 0.4152 - val_loss: 1.4979
# Epoch 5/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.4077 - loss: 1.5172 - val_accuracy: 0.4490 - val_loss: 1.4280
# Epoch 6/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5000 - loss: 1.5407 - val_accuracy: 0.4502 - val_loss: 1.4280
# Epoch 7/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.4492 - loss: 1.4373 - val_accuracy: 0.4878 - val_loss: 1.3514
# Epoch 8/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4688 - loss: 1.3110 - val_accuracy: 0.4890 - val_loss: 1.3500
# Epoch 9/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 17s 23ms/step - accuracy: 0.4754 - loss: 1.3782 - val_accuracy: 0.4988 - val_loss: 1.3021
# Epoch 10/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.3125 - loss: 1.4915 - val_accuracy: 0.5010 - val_loss: 1.3015
# Epoch 11/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - accuracy: 0.4873 - loss: 1.3364 - val_accuracy: 0.5176 - val_loss: 1.2831
# Epoch 12/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.3125 - loss: 1.4254 - val_accuracy: 0.5178 - val_loss: 1.2837
# Epoch 13/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 17s 24ms/step - accuracy: 0.4986 - loss: 1.3130 - val_accuracy: 0.5260 - val_loss: 1.2448
# Epoch 14/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.2812 - loss: 1.6861 - val_accuracy: 0.5239 - val_loss: 1.2453
# Epoch 15/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━
50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 46s 65ms/step - accuracy: 0.5848 - loss: 1.0998 - val_accuracy: 0.5639 - val_loss: 1.1478
# Epoch 44/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.5312 - loss: 1.0515 - val_accuracy: 0.5628 - val_loss: 1.1495
# Epoch 45/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 49s 68ms/step - accuracy: 0.5816 - loss: 1.0924 - val_accuracy: 0.5651 - val_loss: 1.1375
# Epoch 46/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.7188 - loss: 0.9637 - val_accuracy: 0.5658 - val_loss: 1.1388
# Epoch 47/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 67s 93ms/step - accuracy: 0.5860 - loss: 1.0885 - val_accuracy: 0.5656 - val_loss: 1.1467
# Epoch 48/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.5938 - loss: 0.9424 - val_accuracy: 0.5651 - val_loss: 1.1480
# Epoch 49/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 77s 107ms/step - accuracy: 0.5844 - loss: 1.0822 - val_accuracy: 0.5695 - val_loss: 1.1475
# Epoch 50/50
# 717/717 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - accuracy: 0.5000 - loss: 1.1591 - val_accuracy: 0.5688 - val_loss: 1.1475
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step - accuracy: 0.5686 - loss: 1.1284
# Test Accuracy: 57.43%

# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# 加載訓練好的模型
model = load_model('/Users/chenchenghan/Downloads/emotion_detection_fer2013.h5')  # 替換為你訓練好的模型路徑

# 定義情緒標籤
emotion_labels = ['Angry', 'Disgust', 'Fear', 'Happy', 'Neutral', 'Sad', 'Surprise']

# 初始化 OpenCV 的人臉檢測分類器
face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# 啟動攝像頭
cap = cv2.VideoCapture(0)

while True:
    # 從攝像頭捕捉影像
    ret, frame = cap.read()
    if not ret:
        break

    # 將影像轉換為灰階（因為情緒模型使用灰階影像）
    gray_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # 偵測人臉
    faces = face_cascade.detectMultiScale(gray_frame, scaleFactor=1.1, minNeighbors=5)

    for (x, y, w, h) in faces:
        # 繪製人臉邊框
        cv2.rectangle(frame, (x, y), (x+w, y+h), (255, 0, 0), 2)

        # 裁剪人臉影像
        face = gray_frame[y:y+h, x:x+w]
        face = cv2.resize(face, (48, 48))  # 調整大小為模型需要的輸入
        face = face / 255.0  # 正規化
        face = np.expand_dims(face, axis=0)
        face = np.expand_dims(face, axis=-1)  # 添加通道維度 (48, 48, 1)

        # 使用模型進行預測
        emotion_predictions = model.predict(face)
        max_index = np.argmax(emotion_predictions[0])  # 找到預測機率最高的類別
        predicted_emotion = emotion_labels[max_index]

        # 在人臉邊框上方輸出情緒文字
        cv2.putText(frame, predicted_emotion, (x, y-10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 255, 255), 2)

        print(f"Detected emotion: {predicted_emotion}")

    # 顯示影像
    cv2.imshow('Emotion Detection', frame)

    # 按 'q' 鍵退出
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# 釋放資源
cap.release()
cv2.destroyAllWindows()
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# 2024-12-16 15:57:35.347 Python[67790:5490781] WARNING: Secure coding is not enabled for restorable state! Enable secure coding by implementing NSApplicationDelegate.applicationSupportsSecureRestorableState: and returning YES.
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Detected emotion: Fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Fear
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Happy
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Surprise
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Angry
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
# Detected emotion: Neutral
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
# Detected emotion: Neutral
# 在目前儲存格或上一個儲存格中執行程式碼時，Kernel 已損毀。
#
# 請檢閱儲存格中的程式碼，找出失敗的可能原因。
#
# 如需詳細資訊，請按一下<a href='https://aka.ms/vscodeJupyterKernelCrash'>這裡</a>。
#
# 如需詳細資料，請檢視 Jupyter <a href='command:jupyter.viewOutput'>記錄</a>。
